# %%
# !nvidia-smi
#y have to set runenvirment to GPU from CPU
# Out:
# Sun Apr  7 14:27:18 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.1.44-py3-none-any.whl (749 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.2 MB/s eta 0:00:00
# ...

# %%
#install YOLOV8
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 523, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.10/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are {'train', 'predict', 'track', 'val', 'export', 'benchmark'}.
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of {'obb', 'detect', 'segment', 'pose', 'classify'}
#                 MODE (required) is one of {'train', 'predict', 'track', 'val', 'export', 'benchmark'}
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
# ...

# %%
#Train YOLOv8 on a custom dataset
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hhoJNV7nGPfePgWpaxiF")
project = rf.workspace("risztereristvan").project("bugdetection-bzra9")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 9.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
# ...

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/content/bugDetection-1/data.yaml epochs=100 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 210MB/s]
# Ultralytics YOLOv8.1.44 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/runs/detect/train/confusion_matrix.png',width=600)

# %%
Image(filename=f'/content/runs/detect/train/results.png',width=600)

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.1.43 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25843813 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/bugDetection-1/valid/labels.cache... 1976 images, 0 backgrounds, 0 corrupt: 100% 1976/1976 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 124/124 [00:56<00:00,  2.19it/s]
#                    all       1976       2556      0.824      0.707      0.802      0.667
#                Araneae       1976        315      0.816      0.778      0.845      0.708
#             Coleoptera       1976        314      0.787      0.669       0.77      0.648
#                Diptera       1976        402      0.795       0.55      0.729        0.6
#              Hemiptera       1976        395      0.849      0.673      0.759      0.656
#            Hymenoptera       1976        470       0.76      0.545      0.673      0.506
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.5 source={dataset.location}/test/images
# Out:
# Ultralytics YOLOv8.1.44 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25843813 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/989 /content/bugDetection-1/test/images/0019ce6cda02_jpg.rf.8b2022ce1c648ffd4dfb2a72ad30a7c0.jpg: 640x640 1 Araneae, 37.1ms
# image 2/989 /content/bugDetection-1/test/images/001aff3bb822_jpg.rf.a84c2ec437bb309a0f7f6450f6362f61.jpg: 640x640 1 Hymenoptera, 37.1ms
# image 3/989 /content/bugDetection-1/test/images/002648ba222a_jpg.rf.fba1b4158835aa78bdacf947eebd6832.jpg: 640x640 1 Odonata, 37.0ms
# image 4/989 /content/bugDetection-1/test/images/007a168b796e_jpg.rf.00f76ec5f01c6a90a3cb75c3b55900e4.jpg: 640x640 1 Hymenoptera, 37.0ms
# image 5/989 /content/bugDetection-1/test/images/007c868587fe_jpg.rf.712b1bd04b83ad61c64df3786ea10206.jpg: 640x640 1 Odonata, 37.0ms
# image 6/989 /content/bugDetection-1/test/images/00841198dabf_jpg.rf.2933d245759829d168a31c5ab8a11347.jpg: 640x640 1 Diptera, 34.9ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg'):
  display(Image(filename=image_path, height=600))
  print('\n')
